# %%
import speech_recognition as sr

r = sr.Recognizer()

filename = "drake.wav"

# open the file
with sr.AudioFile(filename) as source:
    # listen for the data (load audio to memory)
    audio_data = r.record(source)
    # recognize (convert from speech to text)
    text = r.recognize_google(audio_data)
    print(text)
# Out:
# you used to call me on my cell phone

# %%
from transformers import *

# source & destination languages
src = "en"
dst = "ru"

task_name = f"translation_{src}_to_{dst}"
model_name = f"Helsinki-NLP/opus-mt-{src}-{dst}"

translator  = pipeline(task_name, model=model_name, tokenizer=model_name)

translator(text)[0]["translation_text"]
# Out:
# loading configuration file config.json from cache at C:\Users\mewla/.cache\huggingface\hub\models--Helsinki-NLP--opus-mt-en-ru\snapshots\bb09c99d180016eac6819df3dae68edb1690fdee\config.json
# Model config MarianConfig {
#   "_name_or_path": "Helsinki-NLP/opus-mt-en-ru",
#   "_num_labels": 3,
#   "activation_dropout": 0.0,
#   "activation_function": "swish",
#   "add_bias_logits": false,
#   "add_final_layer_norm": false,
#   "architectures": [
#     "MarianMTModel"
#   ],
#   "attention_dropout": 0.0,
#   "bad_words_ids": [
#     [
#       62517
#     ]
#   ],
#   "bos_token_id": 0,
#   "classif_dropout": 0.0,
#   "classifier_dropout": 0.0,
#   "d_model": 512,
#   "decoder_attention_heads": 8,
#   "decoder_ffn_dim": 2048,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 6,
#   "decoder_start_token_id": 62517,
#   "decoder_vocab_size": 62518,
#   "dropout": 0.1,
#   "encoder_attention_heads": 8,
#   "encoder_ffn_dim": 2048,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 6,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "max_length": 512,
#   "max_position_embeddings": 512,
#   "model_type": "marian",
#   "normalize_before": false,
#   "normalize_embedding": false,
#   "num_beams": 4,
#   "num_hidden_layers": 6,
#   "pad_token_id": 62517,
#   "scale_embedding": true,
#   "share_encoder_decoder_embeddings": true,
#   "static_position_embeddings": true,
#   "transformers_version": "4.35.2",
#   "use_cache": true,
#   "vocab_size": 62518
# }
#
# loading configuration file config.json from cache at C:\Users\mewla/.cache\huggingface\hub\models--Helsinki-NLP--opus-mt-en-ru\snapshots\bb09c99d180016eac6819df3dae68edb1690fdee\config.json
# Model config MarianConfig {
#   "_name_or_path": "Helsinki-NLP/opus-mt-en-ru",
#   "_num_labels": 3,
#   "activation_dropout": 0.0,
#   "activation_function": "swish",
#   "add_bias_logits": false,
#   "add_final_layer_norm": false,
#   "architectures": [
#     "MarianMTModel"
#   ],
#   "attention_dropout": 0.0,
#   "bad_words_ids": [
#     [
#       62517
#     ]
#   ],
#   "bos_token_id": 0,
#   "classif_dropout": 0.0,
#   "classifier_dropout": 0.0,
#   "d_model": 512,
#   "decoder_attention_heads": 8,
#   "decoder_ffn_dim": 2048,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 6,
#   "decoder_start_token_id": 62517,
#   "decoder_vocab_size": 62518,
#   "dropout": 0.1,
#   "encoder_attention_heads": 8,
#   "encoder_ffn_dim": 2048,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 6,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "max_length": 512,
#   "max_position_embeddings": 512,
#   "model_type": "marian",
#   "normalize_before": false,
#   "normalize_embedding": false,
#   "num_beams": 4,
#   "num_hidden_layers": 6,
#   "pad_token_id": 62517,
#   "scale_embedding": true,
#   "share_encoder_decoder_embeddings": true,
#   "static_position_embeddings": true,
#   "transformers_version": "4.35.2",
#   "use_cache": true,
#   "vocab_size": 62518
# }
#
# loading weights file pytorch_model.bin from cache at C:\Users\mewla/.cache\huggingface\hub\models--Helsinki-NLP--opus-mt-en-ru\snapshots\bb09c99d180016eac6819df3dae68edb1690fdee\pytorch_model.bin
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       62517
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 62517,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 62517
# }
#
# All model checkpoint weights were used when initializing MarianMTModel.
#
# All the weights of MarianMTModel were initialized from the model checkpoint at Helsinki-NLP/opus-mt-en-ru.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use MarianMTModel for predictions without further training.
# loading configuration file generation_config.json from cache at C:\Users\mewla/.cache\huggingface\hub\models--Helsinki-NLP--opus-mt-en-ru\snapshots\bb09c99d180016eac6819df3dae68edb1690fdee\generation_config.json
# Generate config GenerationConfig {
#   "bad_words_ids": [
#     [
#       62517
#     ]
#   ],
#   "bos_token_id": 0,
#   "decoder_start_token_id": 62517,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "max_length": 512,
#   "num_beams": 4,
#   "pad_token_id": 62517,
#   "renormalize_logits": true
# }
#
# loading configuration file config.json from cache at C:\Users\mewla/.cache\huggingface\hub\models--Helsinki-NLP--opus-mt-en-ru\snapshots\bb09c99d180016eac6819df3dae68edb1690fdee\config.json
# Model config MarianConfig {
#   "_name_or_path": "Helsinki-NLP/opus-mt-en-ru",
#   "_num_labels": 3,
#   "activation_dropout": 0.0,
#   "activation_function": "swish",
#   "add_bias_logits": false,
#   "add_final_layer_norm": false,
#   "architectures": [
#     "MarianMTModel"
#   ],
#   "attention_dropout": 0.0,
#   "bad_words_ids": [
#     [
#       62517
#     ]
#   ],
#   "bos_token_id": 0,
#   "classif_dropout": 0.0,
#   "classifier_dropout": 0.0,
#   "d_model": 512,
#   "decoder_attention_heads": 8,
#   "decoder_ffn_dim": 2048,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 6,
#   "decoder_start_token_id": 62517,
#   "decoder_vocab_size": 62518,
#   "dropout": 0.1,
#   "encoder_attention_heads": 8,
#   "encoder_ffn_dim": 2048,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 6,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "max_length": 512,
#   "max_position_embeddings": 512,
#   "model_type": "marian",
#   "normalize_before": false,
#   "normalize_embedding": false,
#   "num_beams": 4,
#   "num_hidden_layers": 6,
#   "pad_token_id": 62517,
#   "scale_embedding": true,
#   "share_encoder_decoder_embeddings": true,
#   "static_position_embeddings": true,
#   "transformers_version": "4.35.2",
#   "use_cache": true,
#   "vocab_size": 62518
# }
#
# loading file source.spm from cache at C:\Users\mewla/.cache\huggingface\hub\models--Helsinki-NLP--opus-mt-en-ru\snapshots\bb09c99d180016eac6819df3dae68edb1690fdee\source.spm
# loading file target.spm from cache at C:\Users\mewla/.cache\huggingface\hub\models--Helsinki-NLP--opus-mt-en-ru\snapshots\bb09c99d180016eac6819df3dae68edb1690fdee\target.spm
# loading file vocab.json from cache at C:\Users\mewla/.cache\huggingface\hub\models--Helsinki-NLP--opus-mt-en-ru\snapshots\bb09c99d180016eac6819df3dae68edb1690fdee\vocab.json
# loading file target_vocab.json from cache at None
# loading file tokenizer_config.json from cache at C:\Users\mewla/.cache\huggingface\hub\models--Helsinki-NLP--opus-mt-en-ru\snapshots\bb09c99d180016eac6819df3dae68edb1690fdee\tokenizer_config.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer.json from cache at None
# loading configuration file config.json from cache at C:\Users\mewla/.cache\huggingface\hub\models--Helsinki-NLP--opus-mt-en-ru\snapshots\bb09c99d180016eac6819df3dae68edb1690fdee\config.json
# Model config MarianConfig {
#   "_name_or_path": "Helsinki-NLP/opus-mt-en-ru",
#   "_num_labels": 3,
#   "activation_dropout": 0.0,
#   "activation_function": "swish",
#   "add_bias_logits": false,
#   "add_final_layer_norm": false,
#   "architectures": [
#     "MarianMTModel"
#   ],
#   "attention_dropout": 0.0,
#   "bad_words_ids": [
#     [
#       62517
#     ]
#   ],
#   "bos_token_id": 0,
#   "classif_dropout": 0.0,
#   "classifier_dropout": 0.0,
#   "d_model": 512,
#   "decoder_attention_heads": 8,
#   "decoder_ffn_dim": 2048,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 6,
#   "decoder_start_token_id": 62517,
#   "decoder_vocab_size": 62518,
#   "dropout": 0.1,
#   "encoder_attention_heads": 8,
#   "encoder_ffn_dim": 2048,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 6,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "max_length": 512,
#   "max_position_embeddings": 512,
#   "model_type": "marian",
#   "normalize_before": false,
#   "normalize_embedding": false,
#   "num_beams": 4,
#   "num_hidden_layers": 6,
#   "pad_token_id": 62517,
#   "scale_embedding": true,
#   "share_encoder_decoder_embeddings": true,
#   "static_position_embeddings": true,
#   "transformers_version": "4.35.2",
#   "use_cache": true,
#   "vocab_size": 62518
# }
# 'Ты звонил мне на мобильный.'
